# %% [markdown]
# Tema:
#
# Identificação de falhas em motores elétricos.
#
#
# Problema
#
# Motores elétricos estão presentes em praticamente todos os processos industriais.
#
# A identificação precoce de falhas reduz custos de manutenção, evita paradas inesperadas e aumenta a confiabilidade do sistema.
#
# Neste trabalho será realizada uma análise exploratória de uma base contendo sinais de vibração e acústicos de motores elétricos operando em diferentes condições de velocidade e diferentes estados de funcionamento.
#
# Objetivo Geral
#
# Realizar uma análise exploratória completa de um conjunto de dados reais contendo informações de vibração e sinais acústicos de motores elétricos, identificando padrões, características estatísticas e relações entre as variáveis, preparando a base para uma futura aplicação de técnicas de aprendizado de máquina.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# Leitura dos dados

# %%
df = pd.read_csv("dados/motores.csv")

# %%
Verificando dados

# %%
df.head()

df.info()

df.describe()

df.shape

# %%
Corrigindo inconsistências

# %%
df.isnull().sum()

df.duplicated().sum()

# %% [markdown]
# Ideias de Gŕaficos:
#
# 1 Histograma
#
# Distribuição da vibração
#
# 2 Histograma
#
# Distribuição da frequência acústica
#
# 3 Boxplot
#
# Comparando vibração entre classes
#
# 4 Scatter
#
# Vibração × Ruído
#
# Colorido pela classe.
#
# 5 Heatmap
#
# Correlação
#
# 6 Barras
#
# Quantidade de amostras por tipo de falha
#
# 7 Pairplot
#
# Comparação entre variáveis
#
# 8 Matriz de correlação
#
# Com comentários.
